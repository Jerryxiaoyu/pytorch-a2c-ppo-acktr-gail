# %%
import yaml
import pandas as pd
import os

# %%
exp_id = 14
 
res_path = "/home/drl/PycharmProjects/JerryRepos/pytorch-a2c-ppo-acktr-gail/logs-files/20190929-Kinova_Exp14"

with open(os.path.join(res_path, 'exp_id{}_param.yaml'.format(exp_id)), 'r') as f:
    exps_params = yaml.load(f)

# %%
res_df = pd.DataFrame(exps_params)
res_df.to_csv("res_params.csv")
res_df
# Out:
#                                               exp1                  exp10  \
# _hidden_keys                                    []                     []
# algo                                           ppo                    ppo
# alpha                                         0.99                   0.99
# clip_param                                     0.2                    0.2
# entropy_coef                                  0.01                   0.01
# env_name                     KinovaCupPusherEnv-v0  KinovaCupPusherEnv-v0
# eps                                          1e-05                  1e-05
# gae_lambda                                    0.95                   0.95
# gail_batch_size                                128                    128
# gail_epoch                                       5                      5
# gail_experts_dir                    ./gail_experts         ./gail_experts
# gail_flag                                    False                  False
# ...
